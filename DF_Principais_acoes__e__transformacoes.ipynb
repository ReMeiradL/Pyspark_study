# %% [markdown]
# <a href="https://colab.research.google.com/github/ReMeiradL/Pyspark_study/blob/main/DF_Principais_acoes__e__transformacoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DF - Principais ações e transformações

# %%
#INSTALAR O SPARK NO COLAB
# !pip install pyspark py4j

#IMPORTAR SPARK NO COLAB
from pyspark.sql import SparkSession

#CRIAR SESSÃO SPARK
spark = SparkSession.builder.appName("ExemploPySpark").getOrCreate()

#OBTER CONTEXTO SPARK PARA A SESSÃO
sc = spark.sparkContext

# %% [markdown]
# # Ingestão de dados

# %%
from pyspark.sql.types import *

# %%
arqschema = 'id INT, nome STRING, status STRING, cidade STRING, vendas INT, data STRING'

# %%
despachantes = spark.read.csv('/despachantes.csv', header=False,  schema=arqschema)
despachantes.show()
# Out:
# +---+-------------------+------+-------------+------+----------+
# | id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
# |  1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
# |  2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
# |  3|   Emídio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
# |  4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
# |  5|     Graça Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
# |  6|   Matilde Rebouças| Ativo| Porto Alegre|    22|2019-01-05|
# |  7|    Noêmia   Orriça| Ativo|  Santa Maria|    45|2019-10-05|
# |  8|      Roque Vásquez| Ativo| Porto Alegre|    65|2020-03-05|
# |  9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
# | 10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# +---+-------------------+------+-------------+------+----------+

# %% [markdown]
# # Forma crescente

# %%
despachantes.orderBy("vendas").show()
# Out:
# +---+-------------------+------+-------------+------+----------+
# | id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
# | 10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# |  5|     Graça Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
# |  6|   Matilde Rebouças| Ativo| Porto Alegre|    22|2019-01-05|
# |  1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
# |  2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
# |  3|   Emídio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
# |  4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
# |  7|    Noêmia   Orriça| Ativo|  Santa Maria|    45|2019-10-05|
# |  9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
# |  8|      Roque Vásquez| Ativo| Porto Alegre|    65|2020-03-05|
# +---+-------------------+------+-------------+------+----------+

# %% [markdown]
# # Função - Forma decrescente

# %%
from pyspark.sql import functions as Func

# %%
despachantes.orderBy(Func.col("vendas").desc()).show()
# Out:
# +---+-------------------+------+-------------+------+----------+
# | id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
# |  8|      Roque Vásquez| Ativo| Porto Alegre|    65|2020-03-05|
# |  9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
# |  7|    Noêmia   Orriça| Ativo|  Santa Maria|    45|2019-10-05|
# |  4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
# |  2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
# |  3|   Emídio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
# |  1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
# |  6|   Matilde Rebouças| Ativo| Porto Alegre|    22|2019-01-05|
# |  5|     Graça Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
# | 10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# +---+-------------------+------+-------------+------+----------+

# %% [markdown]
# # Ordenar a cidade e depois do menor para o maior

# %%
despachantes.orderBy(Func.col("cidade").desc(), Func.col("vendas").desc()).show()
# Out:
# +---+-------------------+------+-------------+------+----------+
# | id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
# |  7|    Noêmia   Orriça| Ativo|  Santa Maria|    45|2019-10-05|
# |  1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
# |  8|      Roque Vásquez| Ativo| Porto Alegre|    65|2020-03-05|
# |  9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
# |  4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
# |  3|   Emídio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
# |  6|   Matilde Rebouças| Ativo| Porto Alegre|    22|2019-01-05|
# |  5|     Graça Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
# | 10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# |  2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
# +---+-------------------+------+-------------+------+----------+

# %% [markdown]
# # Importar função SUM

# %%
from pyspark.sql.functions import sum

# %% [markdown]
# # Agrupar as vendas por cidade

# %%
despachantes.groupBy("cidade").agg(sum("vendas")).show()
# Out:
# +-------------+-----------+
# |       cidade|sum(vendas)|
# +-------------+-----------+
# |  Santa Maria|         68|
# |Novo Hamburgo|         34|
# | Porto Alegre|        223|
# +-------------+-----------+

# %%
#ORDENAR CIDADES AGRUPADAS
despachantes.groupBy("cidade").agg(sum("vendas")).orderBy(Func.col("sum(vendas)").desc()).show()
# Out:
# +-------------+-----------+
# |       cidade|sum(vendas)|
# +-------------+-----------+
# | Porto Alegre|        223|
# |  Santa Maria|         68|
# |Novo Hamburgo|         34|
# +-------------+-----------+

# %% [markdown]
# # Filtrar apenas despachantes com o nome Deolinda Vilela

# %%
despachantes.filter(Func.col('nome') == 'Deolinda Vilela').show()
# Out:
# +---+---------------+------+-------------+------+----------+
# | id|           nome|status|       cidade|vendas|      data|
# +---+---------------+------+-------------+------+----------+
# |  2|Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
# +---+---------------+------+-------------+------+----------+
