# %% [markdown]
# <a href="https://colab.research.google.com/github/ReMeiradL/Pyspark_study/blob/main/RDD_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Instalação e criação Pyspark

# %%
#INSTALAR O SPARK NO COLAB
# !pip install pyspark py4j

#IMPORTAR SPARK NO COLAB
from pyspark.sql import SparkSession

#CRIAR SESSÃO SPARK
spark = SparkSession.builder.appName("ExemploPySpark").getOrCreate()

#OBTER CONTEXTO SPARK PARA A SESSÃO
sc = spark.sparkContext
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.12/dist-packages (4.0.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.12/dist-packages (0.10.9.9)

# %% [markdown]
# ### RDD_02

# %%
#CRIAR RDD COMPRAS (CLIENTE, VALOR)
compras = sc.parallelize ([
    (1,200), (2,300), (3,120), (4,250), (5,78)
])

# %%
#EXTRAIR APENAS AS CHAVES
chaves = compras.keys()
#Nesse método "keys", por definição, o primeiro número será a chave.
chaves.collect()
# Out:
# [1, 2, 3, 4, 5]

# %%
#EXTRAIR APENAS OS VALORES
chaves_values = compras.values()
chaves_values.collect()
# Out:
# [200, 300, 120, 250, 78]

# %%
#CONTAGEM POR CHAVE
compras.countByKey()
# Out:
# defaultdict(int, {1: 1, 2: 1, 3: 1, 4: 1, 5: 1})

# %%
#FUNÇÃO NO VALOR SEM ALTERAR A CHAVE
soma = compras.mapValues(lambda soma: soma + 1)
soma.collect()
# Out:
# [(1, 201), (2, 301), (3, 121), (4, 251), (5, 79)]

# %%
#CRIAR RDD DÉBITOS
debitos = sc.parallelize([
    (1,20), (2,300)
])

# %%
#RESULTADO ENTRE COMPRAS E DÉBITO
resultado = compras.join(debitos)
resultado.collect()
# Out:
# [(1, (200, 20)), (2, (300, 300))]

# %%
#MOSTRAR APENAS OS QUE NÃO TEM DÉBITO
semdebito = compras.subtractByKey(debitos)
semdebito.collect()
# Out:
# [(4, 250), (5, 78), (3, 120)]
